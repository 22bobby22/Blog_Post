# %% [markdown]
# # Which countries are more keen to recommend online courses
#
# I will take the first 5 countries with more respondents in the survey, then see which countries have more percentage of respondents that recommend to take online courses.

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#load the data
df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
#get the first 5 countries with more respondents
grouped = df.groupby('Country').count().reset_index()
sortedvalues = grouped.sort_values('Respondent', ascending=False)
countries = sortedvalues['Country'].head()

# %%
#get only the respondents with the countries selected
df2 = df.dropna(subset=['CousinEducation'])
df2 = df2[df2['Country'].isin(countries)]
df2
# Out:
#        Respondent                                       Professional  \
# 18             19                             Professional developer
# 32             33                                      None of these
# 61             62                             Professional developer
# 86             87                             Professional developer
# 92             93                             Professional developer
# ...           ...                                                ...
# 51381       51382  Professional non-developer who sometimes write...
# 51384       51385                             Professional developer
# 51385       51386                Used to be a professional developer
# 51387       51388                             Professional developer
# 51389       51390                             Professional developer
#
#                                     ProgramHobby         Country  \
# 18                     Yes, I program as a hobby   United States
# ...

# %%
#get the respondents that recommend online courses
df3 = df2[df2['CousinEducation'].str.contains('Take online courses')]
df3
# Out:
#        Respondent                                       Professional  \
# 86             87                             Professional developer
# 92             93                             Professional developer
# 112           113                             Professional developer
# 136           137                             Professional developer
# 153           154  Professional non-developer who sometimes write...
# ...           ...                                                ...
# 51380       51381                             Professional developer
# 51381       51382  Professional non-developer who sometimes write...
# 51384       51385                             Professional developer
# 51385       51386                Used to be a professional developer
# 51387       51388                             Professional developer
#
#                     ProgramHobby         Country University  \
# 86                            No         Germany         No
# ...

# %%
#count for each country how many respondents recommend online courses
onlinecount = df3.groupby('Country').size().reset_index(name='Count').sort_values('Count', ascending=False)
onlinecount
# Out:
#           Country  Count
# 4   United States   3363
# 2           India   1489
# 3  United Kingdom   1348
# 1         Germany   1183
# 0          Canada    608

# %%
#total of respondents for each country to calculate the percentages
totalcount = df2.groupby('Country').size().reset_index(name='Total').sort_values('Total', ascending=False)
totalcount
# Out:
#           Country  Total
# 4   United States   5363
# 2           India   2265
# 1         Germany   2137
# 3  United Kingdom   2069
# 0          Canada    971

# %%
#create a dataframe where we can see al the variables together
df4 = onlinecount
df4['Total'] = totalcount['Total']
df4['Percentage'] = df4['Count']/df4['Total']

#show the dataframe sorting by percentages
df4.sort_values('Percentage', ascending=False)
# Out:
#           Country  Count  Total  Percentage
# 2           India   1489   2265    0.657395
# 3  United Kingdom   1348   2069    0.651522
# 4   United States   3363   5363    0.627074
# 0          Canada    608    971    0.626159
# 1         Germany   1183   2137    0.553580

# %%
#select the country and the percentages to create a plot
df5 = df4[['Country', 'Percentage']]
df5
# Out:
#           Country  Percentage
# 4   United States    0.627074
# 2           India    0.657395
# 3  United Kingdom    0.651522
# 1         Germany    0.553580
# 0          Canada    0.626159

# %%
#create the plot
df5.plot(kind='bar', x='Country')

# %% [markdown]
# # Summary
#
# Percentage of respondents that recommend online course:
#
# - India: 65.7%
# - United Kingdom: 65.1%
# - United States: 62.7%
# - Canada: 62.6%
# - Germany: 55.3%

# %% [markdown]
# There is less difference between the countries than I thought there would be at first.
#
# From this data the only interesting thing I would highlight is that there is a 10% difference between Germany and India. Well, the fact that the percentages are more or less equal is interesting by its own.
